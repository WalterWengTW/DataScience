# %% [markdown]
# # 作業目標:
#     寫出 ReLU & dReLU 一階導數
#     並列印

# %% [markdown]
# # 作業重點
#
# # Rectified Linear Unit- Relu
#
# f(x)=max(0,x)

# %%
import numpy as np
from numpy import *
import matplotlib.pylab as plt
# %matplotlib inline

'''
作業:
    寫出 ReLU & dReLU 一階導數
    並列印
'''
def relu(x):  
    return np.maximum(x,0)

def d_relu(x):
    y = x > 0.0
    return y.astype('float32')

x = linspace(-10,10,100)

relu_x = relu(x)

d_relu_x = d_relu(x)

plt.figure(figsize=(10,10))

plt.subplot(2,1,1)

plt.plot(x, relu_x, 'b', label='linspace(-10,10,10)')

plt.title('ReLU')

plt.gca().xaxis.set_major_locator(plt.MultipleLocator(1))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(1))
plt.grid()

plt.subplot(2,1,2)

plt.plot(x, d_relu_x, 'b', label='linspace(-10,10,10)')

plt.title('Derivative of ReLU')

plt.gca().xaxis.set_major_locator(plt.MultipleLocator(1))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(0.1))

plt.grid()
