# %% [markdown]
# # 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# Data Set :
# Energy consumption of the Netherlands
# Electricity and Gas consumed in the Netherlands every year
#
# 1.你選的這組資料為何重要
#
# 透過資料了解能源使用(電力,天然氣)在每個地區有什麼樣的使用特徵
# 用於預測能源使用趨勢用量的預測作為未來使用智慧電表以及能源策略
# (配置電廠，輸電線路，管線增設等)
#
#
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 荷蘭Enexis, Liander, Stedin地區官方提供之open data
# 建築物電表，天然氣管線表頭
#
#
# 3.蒐集而來的資料型態為何
#
# 用電區域，管理機構，每條道路的建築用電總量, 躉購電廠，離峰用電時
# 間能源使用比例，智慧電表建置比率等
#
#
# 4.這組資料想解決的問題如何評估
#
# 使用部分過去資料訓練model並驗證，驗證方式則可透過交叉驗證方法來評估預測模型好壞

# %% [markdown]
# # 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 假設改善到車效率會幫助提升載客量，進而提升業績
# 透過數據分析個因素之間的關聯性
#
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 假設到車效率可能的相關因素，例如:叫車熱點、時段、目的地、道路車況等
# 先建立一般車隊及相關叫車服務機制，紀錄約一年的載客紀錄(包含上述假設的影響因子)
#
#
# 3.蒐集而來的資料型態為何
#
# 每個載客案例包含:
# (1).叫車時間、叫車地點、到車時間
# (2).目的地、車程、價格
# (3).當天天氣、區域路況、季節活動
# 分析出載客熱點、熱門時段等
#
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 每個特徵因素之間對當天載客量影響透過迴歸分析或MLP等機器學習演算
# 得到當天每個區域每個時段應該派遣等待的車輛數來應付該地區該時段的
# 載客服務，提高到車的效率，再透過上述方法執行並記錄，驗證此方法是否有效

# %% [markdown]
# # 作業3：

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 2
b = -50
x_lin = np.linspace(0, 500, 501)
y = (x_lin + np.random.randn(501) * 50) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Data points")
plt.legend(loc = 0)
plt.show()

# %%
yp = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin,yp, 'r-', label = 'prediction')
plt.title("Regression Result")
plt.legend(loc = 2)
plt.show()

# %%
def mean_square_error(y, yp):
    mse = sum((y-yp)**2)/len(y)
    return mse
MSE= mean_square_error(y, yp)
print("The Mean square error is %.3f"%(MSE))
# Out:
# The Mean square error is 10351.448
